# %%
import pandas as pd
df=pd.read_csv("speed_dating.csv", encoding= 'unicode_escape')
pd.set_option('display.max_columns', None)
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
df.shape
# Out:
# (8378, 195)

# %%
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
df["gender"].replace([0,1], ['female', 'male'], inplace=True)
df["match"].replace([0,1], ['no', 'yes'], inplace=True)
df["samerace"].replace([0,1], ['no', 'yes'], inplace=True)
# replace([1,2,3,4,5,6], ['Black', 'European', 'Latino', 'Asian', 'Native American', 'Other'], inplace=True)
df["race_new"] = df["race"].apply(lambda x : "African" if x == 1 else "European" if x == 2 else "Latino" if x == 3 else "Asian" if x == 4 else "Native American" if x == 5 else "Other")
df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0  female    1       1     1     10         7       NaN      4
# 1    1  1.0  female    1       1     1     10         7       NaN      3
# 2    1  1.0  female    1       1     1     10         7       NaN     10
# 3    1  1.0  female    1       1     1     10         7       NaN      5
# 4    1  1.0  female    1       1     1     10         7       NaN      7
#
#    partner   pid match  int_corr samerace  age_o  race_o  pf_o_att  pf_o_sin  \
# 0        1  11.0    no      0.14       no   27.0     2.0      35.0      20.0
# 1        2  12.0    no      0.54       no   22.0     2.0      60.0       0.0
# 2        3  13.0   yes      0.16      yes   22.0     4.0      19.0      18.0
# 3        4  14.0   yes      0.61       no   23.0     2.0      30.0       5.0
# 4        5  15.0   yes      0.21       no   24.0     3.0      30.0      10.0
#
# ...

# %%
# total = df.isnull().sum().sort_values(ascending=False)
# display(total)
percent_null = (df.isnull().sum().sort_values(ascending=False))/(len(df)) 
print(percent_null)
# Out:
# num_in_3    0.920267
# numdat_3    0.821437
# expnum      0.785152
# amb7_2      0.766651
# sinc7_2     0.766651
#               ...
# wave        0.000000
# condtn      0.000000
# idg         0.000000
# gender      0.000000
# race_new    0.000000
# Length: 196, dtype: float64

# %%
# Below code gives percentage of null in every column
null_percentage = df.isnull().sum()/len(df)*100

# Below code gives list of columns having more than 50% null
col_to_drop = null_percentage[null_percentage>50].keys()

output_df = df.drop(col_to_drop, axis=1)

# %%
output_df.shape
# Out:
# (8378, 137)

# %%
percent = (output_df.isnull().sum().sort_values(ascending=False))/(len(output_df)) 
print(percent)
# Out:
# income      0.489258
# amb5_2      0.477560
# fun5_2      0.477560
# intel5_2    0.477560
# sinc5_2     0.477560
#               ...
# wave        0.000000
# condtn      0.000000
# idg         0.000000
# gender      0.000000
# race_new    0.000000
# Length: 137, dtype: float64

# %%
output_df.describe()
# Out:
#                iid           id          idg       condtn         wave  \
# count  8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# mean    283.675937     8.960248    17.327166     1.828837    11.350919
# std     158.583367     5.491329    10.940735     0.376673     5.995903
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%     154.000000     4.000000     8.000000     2.000000     7.000000
# 50%     281.000000     8.000000    16.000000     2.000000    11.000000
# 75%     407.000000    13.000000    26.000000     2.000000    15.000000
# max     552.000000    22.000000    44.000000     2.000000    21.000000
#
#              round     position     positin1        order      partner  \
# count  8378.000000  8378.000000  6532.000000  8378.000000  8378.000000
# mean     16.872046     9.042731     9.295775     8.927668     8.963595
# std       4.358458     5.514939     5.650199     5.477009     5.491068
# ...

# %%
# delete duplicates in "iid"
output_df = output_df.drop_duplicates(subset=['iid'], keep='first')
print("Nb male/female:")
print(output_df.gender.value_counts())
print("---------------")
print("Stats male/female by Age:")
output_df.groupby("gender")["age"].describe(include=all)
# Out:
# Nb male/female:
# male      277
# female    274
# Name: gender, dtype: int64
# ---------------
# Stats male/female by Age:
#         count       mean       std   min   25%   50%   75%   max
# gender
# female  269.0  26.126394  3.997995  19.0  23.0  26.0  28.0  55.0
# male    274.0  26.587591  3.517824  18.0  24.0  27.0  29.0  42.0

# %%
sns.histplot(data=output_df, x="age", hue="gender")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
g = sns.FacetGrid(output_df, row="gender", col="age")
